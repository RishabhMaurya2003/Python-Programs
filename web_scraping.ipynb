# %%
import requests
from bs4 import BeautifulSoup

# Send a GET request to the website
url = 'https://books.toscrape.com/'
response = requests.get(url)

# Parse the page content with BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

# Extract and print the title of the page
print("Page Title: ", soup.title.string)

# Find all the books on the page (each book is in an article tag with class 'product_pod')
books = soup.find_all('article', class_='product_pod')

# Loop through each book and extract title, price, and availability
for idx, book in enumerate(books):
    # Extract book title (inside an <h3> tag within the article)
    title = book.h3.a['title']

    # Extract book price (inside <p> tag with class 'price_color')
    price = book.find('p', class_='price_color').get_text()

    # Extract availability (inside <p> tag with class 'instock availability')
    availability = book.find('p', class_='instock availability').get_text().strip()

    # Print extracted data
    print(f"{idx + 1}. Title: {title}")
    print(f"   Price: {price}")
    print(f"   Availability: {availability}")
    print("-" * 40)
# Out:
# Page Title:
#     All products | Books to Scrape - Sandbox
#
# 1. Title: A Light in the Attic
#    Price: Â£51.77
#    Availability: In stock
# ----------------------------------------
# 2. Title: Tipping the Velvet
#    Price: Â£53.74
#    Availability: In stock
# ----------------------------------------
# 3. Title: Soumission
#    Price: Â£50.10
#    Availability: In stock
# ----------------------------------------
# 4. Title: Sharp Objects
#    Price: Â£47.82
#    Availability: In stock
# ----------------------------------------
# 5. Title: Sapiens: A Brief History of Humankind
#    Price: Â£54.23
#    Availability: In stock
# ----------------------------------------
# 6. Title: The Requiem Red
#    Price: Â£22.65
#    Availability: In stock
# ----------------------------------------
# 7. Title: The Dirty Little Secrets of Getting Your Dream Job
#    Price: Â£33.34
#    Availability: In stock
# ----------------------------------------
# ...
