# %%
import math

# Constants for the game
PLAYER_X = 'X'
PLAYER_O = 'O'
EMPTY = ' '

def print_board(board):
    for row in board:
        print(' | '.join(row))
        print('-' * 9)

def check_winner(board):
    lines = [
        [board[0][0], board[0][1], board[0][2]],
        [board[1][0], board[1][1], board[1][2]],
        [board[2][0], board[2][1], board[2][2]],
        [board[0][0], board[1][0], board[2][0]],
        [board[0][1], board[1][1], board[2][1]],
        [board[0][2], board[1][2], board[2][2]],
        [board[0][0], board[1][1], board[2][2]],
        [board[2][0], board[1][1], board[0][2]],
    ]

    for line in lines:
        if line[0] == line[1] == line[2] and line[0] != EMPTY:
            return line[0]

    if all(cell != EMPTY for row in board for cell in row):
        return 'Tie'

    return None

def minimax(board, depth, is_maximizing):
    winner = check_winner(board)
    if winner == PLAYER_X:
        return -10
    elif winner == PLAYER_O:
        return 10
    elif winner == 'Tie':
        return 0

    if is_maximizing:
        best_score = -math.inf
        for i in range(3):
            for j in range(3):
                if board[i][j] == EMPTY:
                    board[i][j] = PLAYER_O
                    score = minimax(board, depth + 1, False)
                    board[i][j] = EMPTY
                    if depth == 0:  # Only print for the top level
                        print(f"Evaluating move ({i}, {j}) for PLAYER_O: score = {score}")
                    best_score = max(score, best_score)
        if depth == 0:  # Print best score at the top level
            print(f"Best score at depth {depth} for PLAYER_O: {best_score}")
        return best_score
    else:
        best_score = math.inf
        for i in range(3):
            for j in range(3):
                if board[i][j] == EMPTY:
                    board[i][j] = PLAYER_X
                    score = minimax(board, depth + 1, True)
                    board[i][j] = EMPTY
                    if depth == 0:  # Only print for the top level
                        print(f"Evaluating move ({i}, {j}) for PLAYER_X: score = {score}")
                    best_score = min(score, best_score)
        if depth == 0:  # Print best score at the top level
            print(f"Best score at depth {depth} for PLAYER_X: {best_score}")
        return best_score

def find_best_move(board):
    best_score = -math.inf
    move = (-1, -1)
    for i in range(3):
        for j in range(3):
            if board[i][j] == EMPTY:
                board[i][j] = PLAYER_O
                score = minimax(board, 0, False)
                board[i][j] = EMPTY
                if score > best_score:
                    best_score = score
                    move = (i, j)
    print(f"Best move for AI (PLAYER_O): {move} with score = {best_score}")
    return move

def main():
    board = [[EMPTY for _ in range(3)] for _ in range(3)]
    current_player = PLAYER_X

    while True:
        print_board(board)
        if check_winner(board):
            winner = check_winner(board)
            if winner == 'Tie':
                print("It's a Tie!")
            else:
                print(f'Player {winner} wins!')
            break

        if current_player == PLAYER_X:
            row = int(input("Enter row (0, 1, 2): "))
            col = int(input("Enter column (0, 1, 2): "))
            if board[row][col] == EMPTY:
                board[row][col] = PLAYER_X
                current_player = PLAYER_O
            else:
                print("Invalid move, try again.")
        else:
            print("Player O's turn (AI)")
            row, col = find_best_move(board)
            if row != -1 and col != -1:
                board[row][col] = PLAYER_O
                current_player = PLAYER_X

if __name__ == "__main__":
    main()
# Out:
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------
# Enter row (0, 1, 2): 0
# Enter column (0, 1, 2): 0
# X |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------
# Player O's turn (AI)
# Evaluating move (0, 2) for PLAYER_X: score = 0
# Evaluating move (1, 0) for PLAYER_X: score = -10
# Evaluating move (1, 1) for PLAYER_X: score = -10
# Evaluating move (1, 2) for PLAYER_X: score = 0
# Evaluating move (2, 0) for PLAYER_X: score = -10
# Evaluating move (2, 1) for PLAYER_X: score = 0
# Evaluating move (2, 2) for PLAYER_X: score = 0
# Best score at depth 0 for PLAYER_X: -10
# Evaluating move (0, 1) for PLAYER_X: score = 10
# Evaluating move (1, 0) for PLAYER_X: score = -10
# Evaluating move (1, 1) for PLAYER_X: score = 0
# Evaluating move (1, 2) for PLAYER_X: score = 0
# Evaluating move (2, 0) for PLAYER_X: score = -10
# Evaluating move (2, 1) for PLAYER_X: score = 0
# Evaluating move (2, 2) for PLAYER_X: score = -10
# Best score at depth 0 for PLAYER_X: -10
# ...
